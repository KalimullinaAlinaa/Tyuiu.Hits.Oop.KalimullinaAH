// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
// Создать базовый класс BankAccount в C#, который будет представлять
// информацию об учетных записях в банке. На основе этого класса разработать 2-3
// производных класса, демонстрирующих принципы наследования и полиморфизма.
// В каждом из классов должны быть реализованы новые атрибуты и методы, а также
// переопределены некоторые методы базового класса для демонстрации
// полиморфизма.
//
// <b>Требования к базовому классу BankAccount:</b>
// <ul>
//     <li>Атрибуты: Номер счета (AccountNumber), Баланс (Balance), Тип счет (AccountType).</li>
//     <li>Методы:</li>
//     <ul>
//         <li>GetInfo(): метод для получения информации о счете в виде строки.</li>
//         <li>Deposit(decimal amount): метод для внесения денег на счет.</li>
//         <li>Withdraw(decimal amount): метод для снятия денег со счета.</li>
//     </ul>
// </ul>
//
// <b>Требования к производным классам:</b>
//
// <ol>
//     <li>Сберегательный счет (SavingsAccount): Должен содержать дополнительные атрибуты, такие как Процентная ставка (InterestRate). Метод Deposit() должен быть переопределен для добавления процентов к сумме вклада при внесении денег на счет.</li>
//     <li>Текущий счет (CheckingAccount): Должен содержать дополнительные атрибуты, такие как Лимит овердрафта (OverdraftLimit). Метод Withdra () должен быть переопределен для проверки и применения лимита овердрафта при снятии денег со счета.</li>
//     <li>Инвестиционный счет (InvestmentAccount) (если требуется третий класс): Должен содержать дополнительные атрибуты, такие как Список активов (AssetsList). Метод GetInfo() должен быть переопределен для включения информации о списках активов в описании счета.</li>
// </ol>
//
// #### Дополнительное задание
// Добавьте к сущестующим классам конструктора классов с использованием гетторов и сетторов и реализуйте взаимодействие объектов между собой

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
public class BankAccount
{
   
    public string AccountNumber { get; set; }  
    public decimal Balance { get; protected set; }  
    public string AccountType { get; protected set; }  


    public BankAccount(string accountNumber, decimal initialBalance, string accountType)
    {
        AccountNumber = accountNumber;
        Balance = initialBalance;
        AccountType = accountType;
    }


    public virtual string GetInfo()
    {
        return $"Номер счета: {AccountNumber}, Баланс: {Balance:C}, Тип счета: {AccountType}";
    }


    public virtual void Deposit(decimal amount)
    {
        if (amount <= 0)
            throw new ArgumentException("Сумма депозита должна быть положительной.");
        
        Balance += amount;
    }

   
    public virtual void Withdraw(decimal amount)
    {
        if (amount <= 0)
            throw new ArgumentException("Сумма снятия должна быть положительной.");

        if (amount > Balance)
            throw new InvalidOperationException("Недостаточно средств.");
        
        Balance -= amount;
    }

  
    public void Transfer(BankAccount targetAccount, decimal amount)
    {
        if (amount <= 0)
            throw new ArgumentException("Сумма перевода должна быть положительной.");
        else if (AccountType=="Ипотечный")
             throw new ArgumentException("Перевод с ипотечного счета невозможен.");
        Withdraw(amount);
        targetAccount.Deposit(amount);
    }
}


public class SavingsAccount : BankAccount
{
   private decimal interestRate;
   public decimal InterestRate
    {
        get { return interestRate; }
        set
        {
            if (value >= 0)
                interestRate = value;
            else
                throw new ArgumentException("Процентная ставка не может быть отрицательной.");
        }
    }
    public SavingsAccount(string accountNumber, decimal initialBalance, string accountType, decimal interestRate)
        : base(accountNumber, initialBalance, accountType)
    {
        InterestRate = interestRate;
    }

   
    public override void Deposit(decimal amount)
    {
        base.Deposit(amount);
        Balance += Balance * (InterestRate / 100);
    }

    public override string GetInfo()
    {
        return base.GetInfo() + $", Процентная ставка: {InterestRate}%";
    }
}


public class CheckingAccount : BankAccount
{
 
    public decimal OverdraftLimit { get; set; }

    public CheckingAccount(string accountNumber, decimal initialBalance, string accountType, decimal overdraftLimit)
        : base(accountNumber, initialBalance, accountType)
    {
        OverdraftLimit = overdraftLimit;
    }

    public override void Withdraw(decimal amount)
    {
        if (amount <= 0)
            throw new ArgumentOutOfRangeException("Сумма снятия должна быть положительной.");

        if (amount > Balance + OverdraftLimit)
            throw new ArgumentException("Недостаточно средств для снятия, включая лимит овердрафта.");
        
        Balance -= amount;
    }

  
    public override string GetInfo()
    {
        return base.GetInfo() + $", Лимит овердрафта: {OverdraftLimit:C}";
    }
}


public class InvestmentAccount : BankAccount
{
    // список активов
    public List<string> AssetsList { get; set; }

    public InvestmentAccount(string accountNumber, decimal initialBalance, string accountType)
         : base(accountNumber, initialBalance, accountType)
    {
         
        AssetsList = new List<string>();
    }

    // метод для добавления активов
    public void AddAsset(string asset)
    {

        AssetsList.Add(asset);
    }

    public override string GetInfo()
    {
        string assets = AssetsList.Count > 0 ? string.Join(", ", AssetsList) : "Нет активов";
        return base.GetInfo() + $", Активы: {assets}";
    }
}

public class MortgageAccount : BankAccount
{

    private decimal interestRate;

    public decimal InterestRate
    {
        get { return interestRate; }
        set
        {
             if (value >= 0)
                 interestRate = value;
             else
                 throw new ArgumentException("Процентная ставка не может быть отрицательной.");
        }
    }
    public int LoanTermMonths { get; set; }

    public MortgageAccount(string accountNumber, decimal principal, string accountType, decimal interestRate, int loanTermMonths)
        : base(accountNumber, principal, accountType)
    {
        InterestRate = interestRate;
        LoanTermMonths = loanTermMonths;
    }

    // ежемесячны платеж 
    public decimal CalculateMonthlyPayment()
    {
        decimal monthlyRate = InterestRate / 100 / 12;
        decimal monthlypayment = (decimal)Math.Pow((double)(1 + monthlyRate), LoanTermMonths);
        return Balance * monthlyRate * monthlypayment / (monthlypayment - 1);
    }

    public override string GetInfo()
{
    decimal monthlyPayment = CalculateMonthlyPayment();
    decimal monthlyRate = InterestRate / 100 / 12;
    Console.WriteLine(base.GetInfo()); 

    Console.WriteLine($"\n**Процент: {InterestRate}%");
    Console.WriteLine($"**Срок ипотеки: {LoanTermMonths} мес");
    Console.WriteLine($"Ежемесячный платеж: {monthlyPayment:C}\n");
    Console.WriteLine("График платежей:");

    decimal remainingBalance = Balance; 
    for (int month = 1; month <= LoanTermMonths; month++)
    {
        decimal interestPayment = remainingBalance * monthlyRate;
        decimal principalPayment = monthlyPayment - interestPayment;
        remainingBalance -= principalPayment;

        Console.WriteLine($"Месяц {month}: Основной долг: {principalPayment:C}, Платеж по процентам: {interestPayment:C}, Остаток: {remainingBalance:C}");
    }

    return string.Empty; 
}
}
SavingsAccount savingsAccount = new SavingsAccount("12345", 1000, "Сберегательный", 5);
savingsAccount.Deposit(110);
Console.WriteLine(savingsAccount.GetInfo());
 
CheckingAccount checkingAccount = new CheckingAccount("54321", 500, "Текущий", 200);
checkingAccount.Withdraw(300);
Console.WriteLine(checkingAccount.GetInfo());
       
InvestmentAccount investmentAccount = new InvestmentAccount("678910", 1500, "Инвестиционный");
investmentAccount.AddAsset("Акция А123");
investmentAccount.AddAsset("Облигация Б321");
Console.WriteLine(investmentAccount.GetInfo());
// Out:
// Номер счета: 12345, Баланс: ¤1,165.50, Тип счета: Сберегательный, Процентная ставка: 5%
// Номер счета: 54321, Баланс: ¤200.00, Тип счета: Текущий, Лимит овердрафта: ¤200.00
// Номер счета: 678910, Баланс: ¤1,500.00, Тип счета: Инвестиционный, Активы: Акция А123, Облигация Б321

// %%
MortgageAccount mortgageAccount = new MortgageAccount("98765", 80000,"Ипотечный",4, 360);
Console.WriteLine(mortgageAccount.GetInfo());
// Out:
// Номер счета: 98765, Баланс: ¤80,000.00, Тип счета: Ипотечный
//
// **Процент: 4%
// **Срок ипотеки: 360 мес
// Ежемесячный платеж: ¤381.93
//
// График платежей:
// Месяц 1: Основной долг: ¤115.27, Платеж по процентам: ¤266.67, Остаток: ¤79,884.73
// Месяц 2: Основной долг: ¤115.65, Платеж по процентам: ¤266.28, Остаток: ¤79,769.08
// Месяц 3: Основной долг: ¤116.04, Платеж по процентам: ¤265.90, Остаток: ¤79,653.05
// Месяц 4: Основной долг: ¤116.42, Платеж по процентам: ¤265.51, Остаток: ¤79,536.63
// Месяц 5: Основной долг: ¤116.81, Платеж по процентам: ¤265.12, Остаток: ¤79,419.82
// Месяц 6: Основной долг: ¤117.20, Платеж по процентам: ¤264.73, Остаток: ¤79,302.62
// Месяц 7: Основной долг: ¤117.59, Платеж по процентам: ¤264.34, Остаток: ¤79,185.03
// Месяц 8: Основной долг: ¤117.98, Платеж по процентам: ¤263.95, Остаток: ¤79,067.05
// Месяц 9: Основной долг: ¤118.38, Платеж по процентам: ¤263.56, Остаток: ¤78,948.67
// Месяц 10: Основной долг: ¤118.77, Платеж по процентам: ¤263.16, Остаток: ¤78,829.90
// Месяц 11: Основной долг: ¤119.17, Платеж по процентам: ¤262.77, Остаток: ¤78,710.73
// Месяц 12: Основной долг: ¤119.56, Платеж по процентам: ¤262.37, Остаток: ¤78,591.17
// Месяц 13: Основной долг: ¤119.96, Платеж по процентам: ¤261.97, Остаток: ¤78,471.21
// Месяц 14: Основной долг: ¤120.36, Платеж по процентам: ¤261.57, Остаток: ¤78,350.85
// Месяц 15: Основной долг: ¤120.76, Платеж по процентам: ¤261.17, Остаток: ¤78,230.08
// Месяц 16: Основной долг: ¤121.17, Платеж по процентам: ¤260.77, Остаток: ¤78,108.92
// Месяц 17: Основной долг: ¤121.57, Платеж по процентам: ¤260.36, Остаток: ¤77,987.35
// Месяц 18: Основной долг: ¤121.97, Платеж по процентам: ¤259.96, Остаток: ¤77,865.38
// Месяц 19: Основной долг: ¤122.38, Платеж по процентам: ¤259.55, Остаток: ¤77,743.00
// Месяц 20: Основной долг: ¤122.79, Платеж по процентам: ¤259.14, Остаток: ¤77,620.21
// Месяц 21: Основной долг: ¤123.20, Платеж по процентам: ¤258.73, Остаток: ¤77,497.01
// Месяц 22: Основной долг: ¤123.61, Платеж по процентам: ¤258.32, Остаток: ¤77,373.40
// Месяц 23: Основной долг: ¤124.02, Платеж по процентам: ¤257.91, Остаток: ¤77,249.38
// Месяц 24: Основной долг: ¤124.43, Платеж по процентам: ¤257.50, Остаток: ¤77,124.94
// Месяц 25: Основной долг: ¤124.85, Платеж по процентам: ¤257.08, Остаток: ¤77,000.09
// Месяц 26: Основной долг: ¤125.27, Платеж по процентам: ¤256.67, Остаток: ¤76,874.83
// Месяц 27: Основной долг: ¤125.68, Платеж по процентам: ¤256.25, Остаток: ¤76,749.15
// Месяц 28: Основной долг: ¤126.10, Платеж по процентам: ¤255.83, Остаток: ¤76,623.04
// Месяц 29: Основной долг: ¤126.52, Платеж по процентам: ¤255.41, Остаток: ¤76,496.52
// Месяц 30: Основной долг: ¤126.94, Платеж по процентам: ¤254.99, Остаток: ¤76,369.58
// Месяц 31: Основной долг: ¤127.37, Платеж по процентам: ¤254.57, Остаток: ¤76,242.21
// Месяц 32: Основной долг: ¤127.79, Платеж по процентам: ¤254.14, Остаток: ¤76,114.42
// Месяц 33: Основной долг: ¤128.22, Платеж по процентам: ¤253.71, Остаток: ¤75,986.20
// Месяц 34: Основной долг: ¤128.64, Платеж по процентам: ¤253.29, Остаток: ¤75,857.56
// Месяц 35: Основной долг: ¤129.07, Платеж по процентам: ¤252.86, Остаток: ¤75,728.48
// Месяц 36: Основной долг: ¤129.50, Платеж по процентам: ¤252.43, Остаток: ¤75,598.98
// Месяц 37: Основной долг: ¤129.94, Платеж по процентам: ¤252.00, Остаток: ¤75,469.04
// Месяц 38: Основной долг: ¤130.37, Платеж по процентам: ¤251.56, Остаток: ¤75,338.68
// Месяц 39: Основной долг: ¤130.80, Платеж по процентам: ¤251.13, Остаток: ¤75,207.87
// Месяц 40: Основной долг: ¤131.24, Платеж по процентам: ¤250.69, Остаток: ¤75,076.63
// Месяц 41: Основной долг: ¤131.68, Платеж по процентам: ¤250.26, Остаток: ¤74,944.96
// Месяц 42: Основной долг: ¤132.12, Платеж по процентам: ¤249.82, Остаток: ¤74,812.84
// Месяц 43: Основной долг: ¤132.56, Платеж по процентам: ¤249.38, Остаток: ¤74,680.28
// Месяц 44: Основной долг: ¤133.00, Платеж по процентам: ¤248.93, Остаток: ¤74,547.29
// Месяц 45: Основной долг: ¤133.44, Платеж по процентам: ¤248.49, Остаток: ¤74,413.85
// Месяц 46: Основной долг: ¤133.89, Платеж по процентам: ¤248.05, Остаток: ¤74,279.96
// Месяц 47: Основной долг: ¤134.33, Платеж по процентам: ¤247.60, Остаток: ¤74,145.63
// Месяц 48: Основной долг: ¤134.78, Платеж по процентам: ¤247.15, Остаток: ¤74,010.85
// Месяц 49: Основной долг: ¤135.23, Платеж по процентам: ¤246.70, Остаток: ¤73,875.62
// Месяц 50: Основной долг: ¤135.68, Платеж по процентам: ¤246.25, Остаток: ¤73,739.94
// Месяц 51: Основной долг: ¤136.13, Платеж по процентам: ¤245.80, Остаток: ¤73,603.80
// Месяц 52: Основной долг: ¤136.59, Платеж по процентам: ¤245.35, Остаток: ¤73,467.22
// Месяц 53: Основной долг: ¤137.04, Платеж по процентам: ¤244.89, Остаток: ¤73,330.18
// Месяц 54: Основной долг: ¤137.50, Платеж по процентам: ¤244.43, Остаток: ¤73,192.68
// Месяц 55: Основной долг: ¤137.96, Платеж по процентам: ¤243.98, Остаток: ¤73,054.72
// Месяц 56: Основной долг: ¤138.42, Платеж по процентам: ¤243.52, Остаток: ¤72,916.31
// Месяц 57: Основной долг: ¤138.88, Платеж по процентам: ¤243.05, Остаток: ¤72,777.43
// Месяц 58: Основной долг: ¤139.34, Платеж по процентам: ¤242.59, Остаток: ¤72,638.09
// Месяц 59: Основной долг: ¤139.81, Платеж по процентам: ¤242.13, Остаток: ¤72,498.28
// Месяц 60: Основной долг: ¤140.27, Платеж по процентам: ¤241.66, Остаток: ¤72,358.01
// Месяц 61: Основной долг: ¤140.74, Платеж по процентам: ¤241.19, Остаток: ¤72,217.27
// Месяц 62: Основной долг: ¤141.21, Платеж по процентам: ¤240.72, Остаток: ¤72,076.06
// Месяц 63: Основной долг: ¤141.68, Платеж по процентам: ¤240.25, Остаток: ¤71,934.38
// Месяц 64: Основной долг: ¤142.15, Платеж по процентам: ¤239.78, Остаток: ¤71,792.23
// Месяц 65: Основной долг: ¤142.62, Платеж по процентам: ¤239.31, Остаток: ¤71,649.61
// Месяц 66: Основной долг: ¤143.10, Платеж по процентам: ¤238.83, Остаток: ¤71,506.51
// Месяц 67: Основной долг: ¤143.58, Платеж по процентам: ¤238.36, Остаток: ¤71,362.93
// Месяц 68: Основной долг: ¤144.06, Платеж по процентам: ¤237.88, Остаток: ¤71,218.88
// Месяц 69: Основной долг: ¤144.54, Платеж по процентам: ¤237.40, Остаток: ¤71,074.34
// Месяц 70: Основной долг: ¤145.02, Платеж по процентам: ¤236.91, Остаток: ¤70,929.32
// Месяц 71: Основной долг: ¤145.50, Платеж по процентам: ¤236.43, Остаток: ¤70,783.82
// Месяц 72: Основной долг: ¤145.99, Платеж по процентам: ¤235.95, Остаток: ¤70,637.83
// Месяц 73: Основной долг: ¤146.47, Платеж по процентам: ¤235.46, Остаток: ¤70,491.36
// Месяц 74: Основной долг: ¤146.96, Платеж по процентам: ¤234.97, Остаток: ¤70,344.40
// Месяц 75: Основной долг: ¤147.45, Платеж по процентам: ¤234.48, Остаток: ¤70,196.95
// Месяц 76: Основной долг: ¤147.94, Платеж по процентам: ¤233.99, Остаток: ¤70,049.01
// Месяц 77: Основной долг: ¤148.44, Платеж по процентам: ¤233.50, Остаток: ¤69,900.57
// Месяц 78: Основной долг: ¤148.93, Платеж по процентам: ¤233.00, Остаток: ¤69,751.64
// Месяц 79: Основной долг: ¤149.43, Платеж по процентам: ¤232.51, Остаток: ¤69,602.22
// Месяц 80: Основной долг: ¤149.92, Платеж по процентам: ¤232.01, Остаток: ¤69,452.29
// Месяц 81: Основной долг: ¤150.42, Платеж по процентам: ¤231.51, Остаток: ¤69,301.87
// Месяц 82: Основной долг: ¤150.93, Платеж по процентам: ¤231.01, Остаток: ¤69,150.94
// Месяц 83: Основной долг: ¤151.43, Платеж по процентам: ¤230.50, Остаток: ¤68,999.51
// Месяц 84: Основной долг: ¤151.93, Платеж по процентам: ¤230.00, Остаток: ¤68,847.58
// Месяц 85: Основной долг: ¤152.44, Платеж по процентам: ¤229.49, Остаток: ¤68,695.14
// Месяц 86: Основной долг: ¤152.95, Платеж по процентам: ¤228.98, Остаток: ¤68,542.19
// Месяц 87: Основной долг: ¤153.46, Платеж по процентам: ¤228.47, Остаток: ¤68,388.73
// Месяц 88: Основной долг: ¤153.97, Платеж по процентам: ¤227.96, Остаток: ¤68,234.76
// Месяц 89: Основной долг: ¤154.48, Платеж по процентам: ¤227.45, Остаток: ¤68,080.28
// Месяц 90: Основной долг: ¤155.00, Платеж по процентам: ¤226.93, Остаток: ¤67,925.28
// Месяц 91: Основной долг: ¤155.51, Платеж по процентам: ¤226.42, Остаток: ¤67,769.76
// Месяц 92: Основной долг: ¤156.03, Платеж по процентам: ¤225.90, Остаток: ¤67,613.73
// Месяц 93: Основной долг: ¤156.55, Платеж по процентам: ¤225.38, Остаток: ¤67,457.18
// Месяц 94: Основной долг: ¤157.07, Платеж по процентам: ¤224.86, Остаток: ¤67,300.10
// Месяц 95: Основной долг: ¤157.60, Платеж по процентам: ¤224.33, Остаток: ¤67,142.50
// Месяц 96: Основной долг: ¤158.12, Платеж по процентам: ¤223.81, Остаток: ¤66,984.38
// Месяц 97: Основной долг: ¤158.65, Платеж по процентам: ¤223.28, Остаток: ¤66,825.73
// Месяц 98: Основной долг: ¤159.18, Платеж по процентам: ¤222.75, Остаток: ¤66,666.55
// Месяц 99: Основной долг: ¤159.71, Платеж по процентам: ¤222.22, Остаток: ¤66,506.84
// Месяц 100: Основной долг: ¤160.24, Платеж по процентам: ¤221.69, Остаток: ¤66,346.60
// Месяц 101: Основной долг: ¤160.78, Платеж по процентам: ¤221.16, Остаток: ¤66,185.82
// Месяц 102: Основной долг: ¤161.31, Платеж по процентам: ¤220.62, Остаток: ¤66,024.51
// Месяц 103: Основной долг: ¤161.85, Платеж по процентам: ¤220.08, Остаток: ¤65,862.66
// Месяц 104: Основной долг: ¤162.39, Платеж по процентам: ¤219.54, Остаток: ¤65,700.27
// Месяц 105: Основной долг: ¤162.93, Платеж по процентам: ¤219.00, Остаток: ¤65,537.34
// Месяц 106: Основной долг: ¤163.47, Платеж по процентам: ¤218.46, Остаток: ¤65,373.86
// Месяц 107: Основной долг: ¤164.02, Платеж по процентам: ¤217.91, Остаток: ¤65,209.84
// Месяц 108: Основной долг: ¤164.57, Платеж по процентам: ¤217.37, Остаток: ¤65,045.28
// Месяц 109: Основной долг: ¤165.11, Платеж по процентам: ¤216.82, Остаток: ¤64,880.16
// Месяц 110: Основной долг: ¤165.67, Платеж по процентам: ¤216.27, Остаток: ¤64,714.50
// Месяц 111: Основной долг: ¤166.22, Платеж по процентам: ¤215.71, Остаток: ¤64,548.28
// Месяц 112: Основной долг: ¤166.77, Платеж по процентам: ¤215.16, Остаток: ¤64,381.51
// Месяц 113: Основной долг: ¤167.33, Платеж по процентам: ¤214.61, Остаток: ¤64,214.18
// Месяц 114: Основной долг: ¤167.88, Платеж по процентам: ¤214.05, Остаток: ¤64,046.29
// Месяц 115: Основной долг: ¤168.44, Платеж по процентам: ¤213.49, Остаток: ¤63,877.85
// Месяц 116: Основной долг: ¤169.01, Платеж по процентам: ¤212.93, Остаток: ¤63,708.84
// Месяц 117: Основной долг: ¤169.57, Платеж по процентам: ¤212.36, Остаток: ¤63,539.27
// Месяц 118: Основной долг: ¤170.13, Платеж по процентам: ¤211.80, Остаток: ¤63,369.14
// Месяц 119: Основной долг: ¤170.70, Платеж по процентам: ¤211.23, Остаток: ¤63,198.44
// Месяц 120: Основной долг: ¤171.27, Платеж по процентам: ¤210.66, Остаток: ¤63,027.17
// Месяц 121: Основной долг: ¤171.84, Платеж по процентам: ¤210.09, Остаток: ¤62,855.33
// Месяц 122: Основной долг: ¤172.41, Платеж по процентам: ¤209.52, Остаток: ¤62,682.91
// Месяц 123: Основной долг: ¤172.99, Платеж по процентам: ¤208.94, Остаток: ¤62,509.92
// Месяц 124: Основной долг: ¤173.57, Платеж по процентам: ¤208.37, Остаток: ¤62,336.36
// Месяц 125: Основной долг: ¤174.14, Платеж по процентам: ¤207.79, Остаток: ¤62,162.21
// Месяц 126: Основной долг: ¤174.72, Платеж по процентам: ¤207.21, Остаток: ¤61,987.49
// Месяц 127: Основной долг: ¤175.31, Платеж по процентам: ¤206.62, Остаток: ¤61,812.18
// Месяц 128: Основной долг: ¤175.89, Платеж по процентам: ¤206.04, Остаток: ¤61,636.29
// Месяц 129: Основной долг: ¤176.48, Платеж по процентам: ¤205.45, Остаток: ¤61,459.81
// Месяц 130: Основной долг: ¤177.07, Платеж по процентам: ¤204.87, Остаток: ¤61,282.74
// Месяц 131: Основной долг: ¤177.66, Платеж по процентам: ¤204.28, Остаток: ¤61,105.09
// Месяц 132: Основной долг: ¤178.25, Платеж по процентам: ¤203.68, Остаток: ¤60,926.84
// Месяц 133: Основной долг: ¤178.84, Платеж по процентам: ¤203.09, Остаток: ¤60,748.00
// Месяц 134: Основной долг: ¤179.44, Платеж по процентам: ¤202.49, Остаток: ¤60,568.56
// Месяц 135: Основной долг: ¤180.04, Платеж по процентам: ¤201.90, Остаток: ¤60,388.52
// Месяц 136: Основной долг: ¤180.64, Платеж по процентам: ¤201.30, Остаток: ¤60,207.88
// Месяц 137: Основной долг: ¤181.24, Платеж по процентам: ¤200.69, Остаток: ¤60,026.64
// Месяц 138: Основной долг: ¤181.84, Платеж по процентам: ¤200.09, Остаток: ¤59,844.80
// Месяц 139: Основной долг: ¤182.45, Платеж по процентам: ¤199.48, Остаток: ¤59,662.35
// Месяц 140: Основной долг: ¤183.06, Платеж по процентам: ¤198.87, Остаток: ¤59,479.29
// Месяц 141: Основной долг: ¤183.67, Платеж по процентам: ¤198.26, Остаток: ¤59,295.62
// Месяц 142: Основной долг: ¤184.28, Платеж по процентам: ¤197.65, Остаток: ¤59,111.34
// Месяц 143: Основной долг: ¤184.89, Платеж по процентам: ¤197.04, Остаток: ¤58,926.45
// Месяц 144: Основной долг: ¤185.51, Платеж по процентам: ¤196.42, Остаток: ¤58,740.94
// Месяц 145: Основной долг: ¤186.13, Платеж по процентам: ¤195.80, Остаток: ¤58,554.81
// Месяц 146: Основной долг: ¤186.75, Платеж по процентам: ¤195.18, Остаток: ¤58,368.06
// Месяц 147: Основной долг: ¤187.37, Платеж по процентам: ¤194.56, Остаток: ¤58,180.69
// Месяц 148: Основной долг: ¤188.00, Платеж по процентам: ¤193.94, Остаток: ¤57,992.69
// Месяц 149: Основной долг: ¤188.62, Платеж по процентам: ¤193.31, Остаток: ¤57,804.07
// Месяц 150: Основной долг: ¤189.25, Платеж по процентам: ¤192.68, Остаток: ¤57,614.82
// Месяц 151: Основной долг: ¤189.88, Платеж по процентам: ¤192.05, Остаток: ¤57,424.93
// Месяц 152: Основной долг: ¤190.52, Платеж по процентам: ¤191.42, Остаток: ¤57,234.42
// Месяц 153: Основной долг: ¤191.15, Платеж по процентам: ¤190.78, Остаток: ¤57,043.27
// Месяц 154: Основной долг: ¤191.79, Платеж по процентам: ¤190.14, Остаток: ¤56,851.48
// Месяц 155: Основной долг: ¤192.43, Платеж по процентам: ¤189.50, Остаток: ¤56,659.05
// Месяц 156: Основной долг: ¤193.07, Платеж по процентам: ¤188.86, Остаток: ¤56,465.98
// Месяц 157: Основной долг: ¤193.71, Платеж по процентам: ¤188.22, Остаток: ¤56,272.27
// Месяц 158: Основной долг: ¤194.36, Платеж по процентам: ¤187.57, Остаток: ¤56,077.91
// Месяц 159: Основной долг: ¤195.01, Платеж по процентам: ¤186.93, Остаток: ¤55,882.91
// Месяц 160: Основной долг: ¤195.66, Платеж по процентам: ¤186.28, Остаток: ¤55,687.25
// Месяц 161: Основной долг: ¤196.31, Платеж по процентам: ¤185.62, Остаток: ¤55,490.94
// Месяц 162: Основной долг: ¤196.96, Платеж по процентам: ¤184.97, Остаток: ¤55,293.98
// Месяц 163: Основной долг: ¤197.62, Платеж по процентам: ¤184.31, Остаток: ¤55,096.36
// Месяц 164: Основной долг: ¤198.28, Платеж по процентам: ¤183.65, Остаток: ¤54,898.08
// Месяц 165: Основной долг: ¤198.94, Платеж по процентам: ¤182.99, Остаток: ¤54,699.15
// Месяц 166: Основной долг: ¤199.60, Платеж по процентам: ¤182.33, Остаток: ¤54,499.54
// Месяц 167: Основной долг: ¤200.27, Платеж по процентам: ¤181.67, Остаток: ¤54,299.28
// Месяц 168: Основной долг: ¤200.93, Платеж по процентам: ¤181.00, Остаток: ¤54,098.34
// Месяц 169: Основной долг: ¤201.60, Платеж по процентам: ¤180.33, Остаток: ¤53,896.74
// Месяц 170: Основной долг: ¤202.28, Платеж по процентам: ¤179.66, Остаток: ¤53,694.46
// Месяц 171: Основной долг: ¤202.95, Платеж по процентам: ¤178.98, Остаток: ¤53,491.51
// Месяц 172: Основной долг: ¤203.63, Платеж по процентам: ¤178.31, Остаток: ¤53,287.88
// Месяц 173: Основной долг: ¤204.31, Платеж по процентам: ¤177.63, Остаток: ¤53,083.58
// Месяц 174: Основной долг: ¤204.99, Платеж по процентам: ¤176.95, Остаток: ¤52,878.59
// Месяц 175: Основной долг: ¤205.67, Платеж по процентам: ¤176.26, Остаток: ¤52,672.92
// Месяц 176: Основной долг: ¤206.36, Платеж по процентам: ¤175.58, Остаток: ¤52,466.56
// Месяц 177: Основной долг: ¤207.04, Платеж по процентам: ¤174.89, Остаток: ¤52,259.52
// Месяц 178: Основной долг: ¤207.73, Платеж по процентам: ¤174.20, Остаток: ¤52,051.79
// Месяц 179: Основной долг: ¤208.43, Платеж по процентам: ¤173.51, Остаток: ¤51,843.36
// Месяц 180: Основной долг: ¤209.12, Платеж по процентам: ¤172.81, Остаток: ¤51,634.24
// Месяц 181: Основной долг: ¤209.82, Платеж по процентам: ¤172.11, Остаток: ¤51,424.42
// Месяц 182: Основной долг: ¤210.52, Платеж по процентам: ¤171.41, Остаток: ¤51,213.90
// Месяц 183: Основной долг: ¤211.22, Платеж по процентам: ¤170.71, Остаток: ¤51,002.68
// Месяц 184: Основной долг: ¤211.92, Платеж по процентам: ¤170.01, Остаток: ¤50,790.76
// Месяц 185: Основной долг: ¤212.63, Платеж по процентам: ¤169.30, Остаток: ¤50,578.13
// Месяц 186: Основной долг: ¤213.34, Платеж по процентам: ¤168.59, Остаток: ¤50,364.79
// Месяц 187: Основной долг: ¤214.05, Платеж по процентам: ¤167.88, Остаток: ¤50,150.74
// Месяц 188: Основной долг: ¤214.76, Платеж по процентам: ¤167.17, Остаток: ¤49,935.98
// Месяц 189: Основной долг: ¤215.48, Платеж по процентам: ¤166.45, Остаток: ¤49,720.50
// Месяц 190: Основной долг: ¤216.20, Платеж по процентам: ¤165.74, Остаток: ¤49,504.30
// Месяц 191: Основной долг: ¤216.92, Платеж по процентам: ¤165.01, Остаток: ¤49,287.39
// Месяц 192: Основной долг: ¤217.64, Платеж по процентам: ¤164.29, Остаток: ¤49,069.75
// Месяц 193: Основной долг: ¤218.37, Платеж по процентам: ¤163.57, Остаток: ¤48,851.38
// Месяц 194: Основной долг: ¤219.09, Платеж по процентам: ¤162.84, Остаток: ¤48,632.28
// Месяц 195: Основной долг: ¤219.82, Платеж по процентам: ¤162.11, Остаток: ¤48,412.46
// Месяц 196: Основной долг: ¤220.56, Платеж по процентам: ¤161.37, Остаток: ¤48,191.90
// Месяц 197: Основной долг: ¤221.29, Платеж по процентам: ¤160.64, Остаток: ¤47,970.61
// Месяц 198: Основной долг: ¤222.03, Платеж по процентам: ¤159.90, Остаток: ¤47,748.58
// Месяц 199: Основной долг: ¤222.77, Платеж по процентам: ¤159.16, Остаток: ¤47,525.81
// Месяц 200: Основной долг: ¤223.51, Платеж по процентам: ¤158.42, Остаток: ¤47,302.30
// Месяц 201: Основной долг: ¤224.26, Платеж по процентам: ¤157.67, Остаток: ¤47,078.04
// Месяц 202: Основной долг: ¤225.01, Платеж по процентам: ¤156.93, Остаток: ¤46,853.03
// Месяц 203: Основной долг: ¤225.76, Платеж по процентам: ¤156.18, Остаток: ¤46,627.28
// Месяц 204: Основной долг: ¤226.51, Платеж по процентам: ¤155.42, Остаток: ¤46,400.77
// Месяц 205: Основной долг: ¤227.26, Платеж по процентам: ¤154.67, Остаток: ¤46,173.51
// Месяц 206: Основной долг: ¤228.02, Платеж по процентам: ¤153.91, Остаток: ¤45,945.49
// Месяц 207: Основной долг: ¤228.78, Платеж по процентам: ¤153.15, Остаток: ¤45,716.71
// Месяц 208: Основной долг: ¤229.54, Платеж по процентам: ¤152.39, Остаток: ¤45,487.16
// Месяц 209: Основной долг: ¤230.31, Платеж по процентам: ¤151.62, Остаток: ¤45,256.85
// Месяц 210: Основной долг: ¤231.08, Платеж по процентам: ¤150.86, Остаток: ¤45,025.78
// Месяц 211: Основной долг: ¤231.85, Платеж по процентам: ¤150.09, Остаток: ¤44,793.93
// Месяц 212: Основной долг: ¤232.62, Платеж по процентам: ¤149.31, Остаток: ¤44,561.31
// Месяц 213: Основной долг: ¤233.39, Платеж по процентам: ¤148.54, Остаток: ¤44,327.92
// Месяц 214: Основной долг: ¤234.17, Платеж по процентам: ¤147.76, Остаток: ¤44,093.75
// Месяц 215: Основной долг: ¤234.95, Платеж по процентам: ¤146.98, Остаток: ¤43,858.79
// Месяц 216: Основной долг: ¤235.74, Платеж по процентам: ¤146.20, Остаток: ¤43,623.06
// Месяц 217: Основной долг: ¤236.52, Платеж по процентам: ¤145.41, Остаток: ¤43,386.53
// Месяц 218: Основной долг: ¤237.31, Платеж по процентам: ¤144.62, Остаток: ¤43,149.22
// Месяц 219: Основной долг: ¤238.10, Платеж по процентам: ¤143.83, Остаток: ¤42,911.12
// Месяц 220: Основной долг: ¤238.90, Платеж по процентам: ¤143.04, Остаток: ¤42,672.23
// Месяц 221: Основной долг: ¤239.69, Платеж по процентам: ¤142.24, Остаток: ¤42,432.54
// Месяц 222: Основной долг: ¤240.49, Платеж по процентам: ¤141.44, Остаток: ¤42,192.05
// Месяц 223: Основной долг: ¤241.29, Платеж по процентам: ¤140.64, Остаток: ¤41,950.75
// Месяц 224: Основной долг: ¤242.10, Платеж по процентам: ¤139.84, Остаток: ¤41,708.66
// Месяц 225: Основной долг: ¤242.90, Платеж по процентам: ¤139.03, Остаток: ¤41,465.75
// Месяц 226: Основной долг: ¤243.71, Платеж по процентам: ¤138.22, Остаток: ¤41,222.04
// Месяц 227: Основной долг: ¤244.53, Платеж по процентам: ¤137.41, Остаток: ¤40,977.52
// Месяц 228: Основной долг: ¤245.34, Платеж по процентам: ¤136.59, Остаток: ¤40,732.17
// Месяц 229: Основной долг: ¤246.16, Платеж по процентам: ¤135.77, Остаток: ¤40,486.02
// Месяц 230: Основной долг: ¤246.98, Платеж по процентам: ¤134.95, Остаток: ¤40,239.04
// Месяц 231: Основной долг: ¤247.80, Платеж по процентам: ¤134.13, Остаток: ¤39,991.24
// Месяц 232: Основной долг: ¤248.63, Платеж по процентам: ¤133.30, Остаток: ¤39,742.61
// Месяц 233: Основной долг: ¤249.46, Платеж по процентам: ¤132.48, Остаток: ¤39,493.15
// Месяц 234: Основной долг: ¤250.29, Платеж по процентам: ¤131.64, Остаток: ¤39,242.86
// Месяц 235: Основной долг: ¤251.12, Платеж по процентам: ¤130.81, Остаток: ¤38,991.74
// Месяц 236: Основной долг: ¤251.96, Платеж по процентам: ¤129.97, Остаток: ¤38,739.78
// Месяц 237: Основной долг: ¤252.80, Платеж по процентам: ¤129.13, Остаток: ¤38,486.98
// Месяц 238: Основной долг: ¤253.64, Платеж по процентам: ¤128.29, Остаток: ¤38,233.34
// Месяц 239: Основной долг: ¤254.49, Платеж по процентам: ¤127.44, Остаток: ¤37,978.85
// Месяц 240: Основной долг: ¤255.34, Платеж по процентам: ¤126.60, Остаток: ¤37,723.51
// Месяц 241: Основной долг: ¤256.19, Платеж по процентам: ¤125.75, Остаток: ¤37,467.33
// Месяц 242: Основной долг: ¤257.04, Платеж по процентам: ¤124.89, Остаток: ¤37,210.29
// Месяц 243: Основной долг: ¤257.90, Платеж по процентам: ¤124.03, Остаток: ¤36,952.39
// Месяц 244: Основной долг: ¤258.76, Платеж по процентам: ¤123.17, Остаток: ¤36,693.63
// Месяц 245: Основной долг: ¤259.62, Платеж по процентам: ¤122.31, Остаток: ¤36,434.01
// Месяц 246: Основной долг: ¤260.49, Платеж по процентам: ¤121.45, Остаток: ¤36,173.52
// Месяц 247: Основной долг: ¤261.35, Платеж по процентам: ¤120.58, Остаток: ¤35,912.17
// Месяц 248: Основной долг: ¤262.23, Платеж по процентам: ¤119.71, Остаток: ¤35,649.95
// Месяц 249: Основной долг: ¤263.10, Платеж по процентам: ¤118.83, Остаток: ¤35,386.85
// Месяц 250: Основной долг: ¤263.98, Платеж по процентам: ¤117.96, Остаток: ¤35,122.87
// Месяц 251: Основной долг: ¤264.86, Платеж по процентам: ¤117.08, Остаток: ¤34,858.01
// Месяц 252: Основной долг: ¤265.74, Платеж по процентам: ¤116.19, Остаток: ¤34,592.28
// Месяц 253: Основной долг: ¤266.62, Платеж по процентам: ¤115.31, Остаток: ¤34,325.65
// Месяц 254: Основной долг: ¤267.51, Платеж по процентам: ¤114.42, Остаток: ¤34,058.14
// Месяц 255: Основной долг: ¤268.41, Платеж по процентам: ¤113.53, Остаток: ¤33,789.73
// Месяц 256: Основной долг: ¤269.30, Платеж по процентам: ¤112.63, Остаток: ¤33,520.43
// Месяц 257: Основной долг: ¤270.20, Платеж по процентам: ¤111.73, Остаток: ¤33,250.23
// Месяц 258: Основной долг: ¤271.10, Платеж по процентам: ¤110.83, Остаток: ¤32,979.14
// Месяц 259: Основной долг: ¤272.00, Платеж по процентам: ¤109.93, Остаток: ¤32,707.14
// Месяц 260: Основной долг: ¤272.91, Платеж по процентам: ¤109.02, Остаток: ¤32,434.23
// Месяц 261: Основной долг: ¤273.82, Платеж по процентам: ¤108.11, Остаток: ¤32,160.41
// Месяц 262: Основной долг: ¤274.73, Платеж по процентам: ¤107.20, Остаток: ¤31,885.68
// Месяц 263: Основной долг: ¤275.65, Платеж по процентам: ¤106.29, Остаток: ¤31,610.03
// Месяц 264: Основной долг: ¤276.57, Платеж по процентам: ¤105.37, Остаток: ¤31,333.47
// Месяц 265: Основной долг: ¤277.49, Платеж по процентам: ¤104.44, Остаток: ¤31,055.98
// Месяц 266: Основной долг: ¤278.41, Платеж по процентам: ¤103.52, Остаток: ¤30,777.57
// Месяц 267: Основной долг: ¤279.34, Платеж по процентам: ¤102.59, Остаток: ¤30,498.23
// Месяц 268: Основной долг: ¤280.27, Платеж по процентам: ¤101.66, Остаток: ¤30,217.95
// Месяц 269: Основной долг: ¤281.21, Платеж по процентам: ¤100.73, Остаток: ¤29,936.75
// Месяц 270: Основной долг: ¤282.14, Платеж по процентам: ¤99.79, Остаток: ¤29,654.61
// Месяц 271: Основной долг: ¤283.08, Платеж по процентам: ¤98.85, Остаток: ¤29,371.52
// Месяц 272: Основной долг: ¤284.03, Платеж по процентам: ¤97.91, Остаток: ¤29,087.49
// Месяц 273: Основной долг: ¤284.97, Платеж по процентам: ¤96.96, Остаток: ¤28,802.52
// Месяц 274: Основной долг: ¤285.92, Платеж по процентам: ¤96.01, Остаток: ¤28,516.60
// Месяц 275: Основной долг: ¤286.88, Платеж по процентам: ¤95.06, Остаток: ¤28,229.72
// Месяц 276: Основной долг: ¤287.83, Платеж по процентам: ¤94.10, Остаток: ¤27,941.89
// Месяц 277: Основной долг: ¤288.79, Платеж по процентам: ¤93.14, Остаток: ¤27,653.09
// Месяц 278: Основной долг: ¤289.76, Платеж по процентам: ¤92.18, Остаток: ¤27,363.34
// Месяц 279: Основной долг: ¤290.72, Платеж по процентам: ¤91.21, Остаток: ¤27,072.62
// Месяц 280: Основной долг: ¤291.69, Платеж по процентам: ¤90.24, Остаток: ¤26,780.93
// Месяц 281: Основной долг: ¤292.66, Платеж по процентам: ¤89.27, Остаток: ¤26,488.26
// Месяц 282: Основной долг: ¤293.64, Платеж по процентам: ¤88.29, Остаток: ¤26,194.63
// Месяц 283: Основной долг: ¤294.62, Платеж по процентам: ¤87.32, Остаток: ¤25,900.01
// Месяц 284: Основной долг: ¤295.60, Платеж по процентам: ¤86.33, Остаток: ¤25,604.41
// Месяц 285: Основной долг: ¤296.58, Платеж по процентам: ¤85.35, Остаток: ¤25,307.83
// Месяц 286: Основной долг: ¤297.57, Платеж по процентам: ¤84.36, Остаток: ¤25,010.25
// Месяц 287: Основной долг: ¤298.56, Платеж по процентам: ¤83.37, Остаток: ¤24,711.69
// Месяц 288: Основной долг: ¤299.56, Платеж по процентам: ¤82.37, Остаток: ¤24,412.13
// Месяц 289: Основной долг: ¤300.56, Платеж по процентам: ¤81.37, Остаток: ¤24,111.57
// Месяц 290: Основной долг: ¤301.56, Платеж по процентам: ¤80.37, Остаток: ¤23,810.01
// Месяц 291: Основной долг: ¤302.57, Платеж по процентам: ¤79.37, Остаток: ¤23,507.45
// Месяц 292: Основной долг: ¤303.57, Платеж по процентам: ¤78.36, Остаток: ¤23,203.87
// Месяц 293: Основной долг: ¤304.59, Платеж по процентам: ¤77.35, Остаток: ¤22,899.29
// Месяц 294: Основной долг: ¤305.60, Платеж по процентам: ¤76.33, Остаток: ¤22,593.68
// Месяц 295: Основной долг: ¤306.62, Платеж по процентам: ¤75.31, Остаток: ¤22,287.06
// Месяц 296: Основной долг: ¤307.64, Платеж по процентам: ¤74.29, Остаток: ¤21,979.42
// Месяц 297: Основной долг: ¤308.67, Платеж по процентам: ¤73.26, Остаток: ¤21,670.75
// Месяц 298: Основной долг: ¤309.70, Платеж по процентам: ¤72.24, Остаток: ¤21,361.06
// Месяц 299: Основной долг: ¤310.73, Платеж по процентам: ¤71.20, Остаток: ¤21,050.33
// Месяц 300: Основной долг: ¤311.76, Платеж по процентам: ¤70.17, Остаток: ¤20,738.56
// Месяц 301: Основной долг: ¤312.80, Платеж по процентам: ¤69.13, Остаток: ¤20,425.76
// Месяц 302: Основной долг: ¤313.85, Платеж по процентам: ¤68.09, Остаток: ¤20,111.91
// Месяц 303: Основной долг: ¤314.89, Платеж по процентам: ¤67.04, Остаток: ¤19,797.02
// Месяц 304: Основной долг: ¤315.94, Платеж по процентам: ¤65.99, Остаток: ¤19,481.08
// Месяц 305: Основной долг: ¤317.00, Платеж по процентам: ¤64.94, Остаток: ¤19,164.08
// Месяц 306: Основной долг: ¤318.05, Платеж по процентам: ¤63.88, Остаток: ¤18,846.03
// Месяц 307: Основной долг: ¤319.11, Платеж по процентам: ¤62.82, Остаток: ¤18,526.92
// Месяц 308: Основной долг: ¤320.18, Платеж по процентам: ¤61.76, Остаток: ¤18,206.74
// Месяц 309: Основной долг: ¤321.24, Платеж по процентам: ¤60.69, Остаток: ¤17,885.50
// Месяц 310: Основной долг: ¤322.31, Платеж по процентам: ¤59.62, Остаток: ¤17,563.19
// Месяц 311: Основной долг: ¤323.39, Платеж по процентам: ¤58.54, Остаток: ¤17,239.80
// Месяц 312: Основной долг: ¤324.47, Платеж по процентам: ¤57.47, Остаток: ¤16,915.33
// Месяц 313: Основной долг: ¤325.55, Платеж по процентам: ¤56.38, Остаток: ¤16,589.79
// Месяц 314: Основной долг: ¤326.63, Платеж по процентам: ¤55.30, Остаток: ¤16,263.15
// Месяц 315: Основной долг: ¤327.72, Платеж по процентам: ¤54.21, Остаток: ¤15,935.43
// Месяц 316: Основной долг: ¤328.81, Платеж по процентам: ¤53.12, Остаток: ¤15,606.62
// Месяц 317: Основной долг: ¤329.91, Платеж по процентам: ¤52.02, Остаток: ¤15,276.71
// Месяц 318: Основной долг: ¤331.01, Платеж по процентам: ¤50.92, Остаток: ¤14,945.70
// Месяц 319: Основной долг: ¤332.11, Платеж по процентам: ¤49.82, Остаток: ¤14,613.58
// Месяц 320: Основной долг: ¤333.22, Платеж по процентам: ¤48.71, Остаток: ¤14,280.36
// Месяц 321: Основной долг: ¤334.33, Платеж по процентам: ¤47.60, Остаток: ¤13,946.03
// Месяц 322: Основной долг: ¤335.45, Платеж по процентам: ¤46.49, Остаток: ¤13,610.59
// Месяц 323: Основной долг: ¤336.56, Платеж по процентам: ¤45.37, Остаток: ¤13,274.02
// Месяц 324: Основной долг: ¤337.69, Платеж по процентам: ¤44.25, Остаток: ¤12,936.34
// Месяц 325: Основной долг: ¤338.81, Платеж по процентам: ¤43.12, Остаток: ¤12,597.53
// Месяц 326: Основной долг: ¤339.94, Платеж по процентам: ¤41.99, Остаток: ¤12,257.59
// Месяц 327: Основной долг: ¤341.07, Платеж по процентам: ¤40.86, Остаток: ¤11,916.51
// Месяц 328: Основной долг: ¤342.21, Платеж по процентам: ¤39.72, Остаток: ¤11,574.30
// Месяц 329: Основной долг: ¤343.35, Платеж по процентам: ¤38.58, Остаток: ¤11,230.95
// Месяц 330: Основной долг: ¤344.50, Платеж по процентам: ¤37.44, Остаток: ¤10,886.45
// Месяц 331: Основной долг: ¤345.64, Платеж по процентам: ¤36.29, Остаток: ¤10,540.81
// Месяц 332: Основной долг: ¤346.80, Платеж по процентам: ¤35.14, Остаток: ¤10,194.01
// Месяц 333: Основной долг: ¤347.95, Платеж по процентам: ¤33.98, Остаток: ¤9,846.06
// Месяц 334: Основной долг: ¤349.11, Платеж по процентам: ¤32.82, Остаток: ¤9,496.95
// Месяц 335: Основной долг: ¤350.28, Платеж по процентам: ¤31.66, Остаток: ¤9,146.67
// Месяц 336: Основной долг: ¤351.44, Платеж по процентам: ¤30.49, Остаток: ¤8,795.23
// Месяц 337: Основной долг: ¤352.61, Платеж по процентам: ¤29.32, Остаток: ¤8,442.62
// Месяц 338: Основной долг: ¤353.79, Платеж по процентам: ¤28.14, Остаток: ¤8,088.83
// Месяц 339: Основной долг: ¤354.97, Платеж по процентам: ¤26.96, Остаток: ¤7,733.86
// Месяц 340: Основной долг: ¤356.15, Платеж по процентам: ¤25.78, Остаток: ¤7,377.70
// Месяц 341: Основной долг: ¤357.34, Платеж по процентам: ¤24.59, Остаток: ¤7,020.36
// Месяц 342: Основной долг: ¤358.53, Платеж по процентам: ¤23.40, Остаток: ¤6,661.83
// Месяц 343: Основной долг: ¤359.73, Платеж по процентам: ¤22.21, Остаток: ¤6,302.11
// Месяц 344: Основной долг: ¤360.93, Платеж по процентам: ¤21.01, Остаток: ¤5,941.18
// Месяц 345: Основной долг: ¤362.13, Платеж по процентам: ¤19.80, Остаток: ¤5,579.05
// Месяц 346: Основной долг: ¤363.34, Платеж по процентам: ¤18.60, Остаток: ¤5,215.72
// Месяц 347: Основной долг: ¤364.55, Платеж по процентам: ¤17.39, Остаток: ¤4,851.17
// Месяц 348: Основной долг: ¤365.76, Платеж по процентам: ¤16.17, Остаток: ¤4,485.41
// Месяц 349: Основной долг: ¤366.98, Платеж по процентам: ¤14.95, Остаток: ¤4,118.43
// Месяц 350: Основной долг: ¤368.20, Платеж по процентам: ¤13.73, Остаток: ¤3,750.23
// Месяц 351: Основной долг: ¤369.43, Платеж по процентам: ¤12.50, Остаток: ¤3,380.79
// Месяц 352: Основной долг: ¤370.66, Платеж по процентам: ¤11.27, Остаток: ¤3,010.13
// Месяц 353: Основной долг: ¤371.90, Платеж по процентам: ¤10.03, Остаток: ¤2,638.23
// Месяц 354: Основной долг: ¤373.14, Платеж по процентам: ¤8.79, Остаток: ¤2,265.09
// Месяц 355: Основной долг: ¤374.38, Платеж по процентам: ¤7.55, Остаток: ¤1,890.71
// Месяц 356: Основной долг: ¤375.63, Платеж по процентам: ¤6.30, Остаток: ¤1,515.08
// Месяц 357: Основной долг: ¤376.88, Платеж по процентам: ¤5.05, Остаток: ¤1,138.20
// Месяц 358: Основной долг: ¤378.14, Платеж по процентам: ¤3.79, Остаток: ¤760.06
// Месяц 359: Основной долг: ¤379.40, Платеж по процентам: ¤2.53, Остаток: ¤380.66
// Месяц 360: Основной долг: ¤380.66, Платеж по процентам: ¤1.27, Остаток: ¤0.00

// %%
savingsAccount.Transfer(mortgageAccount, 1000);
Console.WriteLine(savingsAccount.GetInfo());
Console.WriteLine(mortgageAccount.GetInfo());
// Out:
// System.InvalidOperationException: Недостаточно средств.
//
//    at Submission#23.BankAccount.Withdraw(Decimal amount)
//
//    at Submission#23.BankAccount.Transfer(BankAccount targetAccount, Decimal amount)
//
//    at Submission#37.<<Initialize>>d__0.MoveNext()
//
// --- End of stack trace from previous location ---
//
//    at Microsoft.CodeAnalysis.Scripting.ScriptExecutionState.RunSubmissionsAsync[TResult](ImmutableArray`1 precedingExecutors, Func`2 currentExecutor, StrongBox`1 exceptionHolderOpt, Func`2 catchExceptionOpt, CancellationToken cancellationToken)

// %%
public class BankAccAvg
{
    public int Avg(CheckingAccount checking, InvestmentAccount invest, SavingsAccount saving)
    {
        decimal totalBalance = checking.Balance + saving.Balance + invest.Balance;
        int avgBalance = Convert.ToInt32(totalBalance / 3);
        return avgBalance;
    }
    
BankAccAvg avg = new BankAccAvg();
Console.WriteLine("Средний баланс: " + avg.Avg(checkingAccount, investmentAccount, savingsAccount));

// %%
 public override string GetInfo()
    {
        return $"Баланс:{Balance:C}";
    }
